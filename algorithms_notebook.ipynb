# %%
import my_modules as mm 

mod = mm.MySortingClass()
a = [1,23,53,2,43,357,8765,343,4,234,42,54,2,4,545,23456,65654]
# a = []

sorted_list = mod.selection_sort(a,reverse=True)
print(sorted_list)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import my_modules as mm
#       3 mod = mm.MySortingClass()
#       4 a = [1,23,53,2,43,357,8765,343,4,234,42,54,2,4,545,23456,65654]
#
# File ~/EDU/Playground_1/Algorithms/my_modules/__init__.py:2
#       1 # my_modules/__init__.py
# ----> 2 from .modules import MySortingClass
#
# ImportError: cannot import name 'MySortingClass' from 'my_modules.modules' (/Users/andrey/EDU/Playground_1/Algorithms/my_modules/modules.py)

# %%
sorted([])
# Out:
# []

# %%
import numpy as np
